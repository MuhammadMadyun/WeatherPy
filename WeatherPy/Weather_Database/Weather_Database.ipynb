# %%
# Import dependencies.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
##################################################
# Make a 'Get' request for the city weather.
city_weather = requests.get(url)
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":56.16,"feels_like":52.79,"temp_min":52,"temp_max":59,"pressure":1008,"humidity":28},"visibility":10000,"wind":{"speed":20.71,"deg":340,"gust":27.63},"clouds":{"all":90},"dt":1617653766,"sys":{"type":1,"id":3486,"country":"US","sunrise":1617617956,"sunset":1617664442},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# list to hold weather data
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_json["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | grindavik
# Processing Record 6 of Set 1 | egvekinot
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | tonekabon
# Processing Record 10 of Set 1 | tuskegee
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | coihaique
# Processing Record 13 of Set 1 | maceio
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | waddan
# Processing Record 16 of Set 1 | thap khlo
# Processing Record 17 of Set 1 | orahovac
# Processing Record 18 of Set 1 | olkhovatka
# Processing Record 19 of Set 1 | haimen
# Processing Record 20 of Set 1 | andenes
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | miri
# Processing Record 23 of Set 1 | chumikan
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | sarkand
# Processing Record 26 of Set 1 | callaway
# Processing Record 27 of Set 1 | porosozero
# Processing Record 28 of Set 1 | buraydah
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | umm durman
# City not found. Skipping...
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | port hardy
# Processing Record 33 of Set 1 | imeni poliny osipenko
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | eenhana
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | asau
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | cherskiy
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | gizo
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | north bend
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | kieta
# Processing Record 46 of Set 1 | vokhtoga
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | bethel
# Processing Record 2 of Set 2 | dalsingh sarai
# Processing Record 3 of Set 2 | srednekolymsk
# Processing Record 4 of Set 2 | strezhevoy
# Processing Record 5 of Set 2 | susangerd
# Processing Record 6 of Set 2 | comodoro rivadavia
# Processing Record 7 of Set 2 | myrtle beach
# Processing Record 8 of Set 2 | kaitangata
# Processing Record 9 of Set 2 | ilhabela
# Processing Record 10 of Set 2 | ancud
# Processing Record 11 of Set 2 | cidreira
# Processing Record 12 of Set 2 | meridian
# Processing Record 13 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 2 | lavrentiya
# Processing Record 15 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 2 | hwange
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | barra
# Processing Record 20 of Set 2 | san patricio
# Processing Record 21 of Set 2 | tiksi
# Processing Record 22 of Set 2 | constitucion
# Processing Record 23 of Set 2 | zarubino
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | chokurdakh
# Processing Record 26 of Set 2 | lebu
# Processing Record 27 of Set 2 | bengkulu
# Processing Record 28 of Set 2 | souillac
# Processing Record 29 of Set 2 | yingzhong
# City not found. Skipping...
# Processing Record 30 of Set 2 | libreville
# Processing Record 31 of Set 2 | khatanga
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | villamontes
# Processing Record 35 of Set 2 | praia
# Processing Record 36 of Set 2 | vestmannaeyjar
# Processing Record 37 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 2 | talnakh
# Processing Record 39 of Set 2 | gat
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | pitsunda
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | guerrero negro
# Processing Record 44 of Set 2 | avera
# Processing Record 45 of Set 2 | padang
# Processing Record 46 of Set 2 | busselton
# Processing Record 47 of Set 2 | saint-philippe
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | tongren
# Processing Record 50 of Set 2 | klaksvik
# Processing Record 1 of Set 3 | ponta do sol
# Processing Record 2 of Set 3 | mecca
# Processing Record 3 of Set 3 | muskogee
# Processing Record 4 of Set 3 | chemal
# Processing Record 5 of Set 3 | loandjili
# Processing Record 6 of Set 3 | pafos
# Processing Record 7 of Set 3 | vila franca do campo
# Processing Record 8 of Set 3 | vicente guerrero
# Processing Record 9 of Set 3 | fairbanks
# Processing Record 10 of Set 3 | portland
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | sao felix do xingu
# Processing Record 14 of Set 3 | paderborn
# Processing Record 15 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 16 of Set 3 | tambun
# Processing Record 17 of Set 3 | george
# Processing Record 18 of Set 3 | pisco
# Processing Record 19 of Set 3 | dhrol
# Processing Record 20 of Set 3 | faya
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | aklavik
# Processing Record 23 of Set 3 | geraldton
# Processing Record 24 of Set 3 | kijang
# Processing Record 25 of Set 3 | mar del plata
# Processing Record 26 of Set 3 | dicabisagan
# Processing Record 27 of Set 3 | shenxian
# Processing Record 28 of Set 3 | hovd
# Processing Record 29 of Set 3 | mataura
# Processing Record 30 of Set 3 | hangu
# Processing Record 31 of Set 3 | catamarca
# Processing Record 32 of Set 3 | cabo san lucas
# Processing Record 33 of Set 3 | castro
# Processing Record 34 of Set 3 | mangrol
# Processing Record 35 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 3 | wawa
# Processing Record 37 of Set 3 | alofi
# Processing Record 38 of Set 3 | bathsheba
# Processing Record 39 of Set 3 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 40 of Set 3 | half moon bay
# Processing Record 41 of Set 3 | verkhnevilyuysk
# Processing Record 42 of Set 3 | tigil
# Processing Record 43 of Set 3 | alice springs
# Processing Record 44 of Set 3 | kapaa
# Processing Record 45 of Set 3 | dunedin
# Processing Record 46 of Set 3 | faanui
# Processing Record 47 of Set 3 | yenagoa
# Processing Record 48 of Set 3 | kuala terengganu
# Processing Record 49 of Set 3 | bayji
# Processing Record 50 of Set 3 | iqaluit
# Processing Record 1 of Set 4 | skibbereen
# Processing Record 2 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 4 | hillsborough
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | severo-kurilsk
# Processing Record 8 of Set 4 | huarmey
# Processing Record 9 of Set 4 | chifeng
# Processing Record 10 of Set 4 | isangel
# Processing Record 11 of Set 4 | kudahuvadhoo
# Processing Record 12 of Set 4 | severomuysk
# Processing Record 13 of Set 4 | zaragoza
# Processing Record 14 of Set 4 | westport
# Processing Record 15 of Set 4 | new norfolk
# Processing Record 16 of Set 4 | ilo
# Processing Record 17 of Set 4 | arraial do cabo
# Processing Record 18 of Set 4 | provideniya
# Processing Record 19 of Set 4 | jonesboro
# Processing Record 20 of Set 4 | bam
# Processing Record 21 of Set 4 | nikolskoye
# Processing Record 22 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 23 of Set 4 | machico
# Processing Record 24 of Set 4 | narsaq
# Processing Record 25 of Set 4 | najran
# Processing Record 26 of Set 4 | gallatin
# Processing Record 27 of Set 4 | benguela
# Processing Record 28 of Set 4 | georgetown
# Processing Record 29 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 30 of Set 4 | linxia
# Processing Record 31 of Set 4 | jamestown
# Processing Record 32 of Set 4 | hasaki
# Processing Record 33 of Set 4 | taoudenni
# Processing Record 34 of Set 4 | puerto ayora
# Processing Record 35 of Set 4 | laguna
# Processing Record 36 of Set 4 | srivardhan
# Processing Record 37 of Set 4 | fortuna
# Processing Record 38 of Set 4 | pevek
# Processing Record 39 of Set 4 | saldanha
# Processing Record 40 of Set 4 | adrar
# Processing Record 41 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 4 | nabire
# Processing Record 43 of Set 4 | grand forks
# Processing Record 44 of Set 4 | rampura
# Processing Record 45 of Set 4 | neuenhagen
# Processing Record 46 of Set 4 | wanaka
# Processing Record 47 of Set 4 | la sarre
# Processing Record 48 of Set 4 | kruisfontein
# Processing Record 49 of Set 4 | rawson
# Processing Record 50 of Set 4 | hauterive
# Processing Record 1 of Set 5 | swidnik
# Processing Record 2 of Set 5 | aloleng
# Processing Record 3 of Set 5 | tabuk
# Processing Record 4 of Set 5 | torbay
# Processing Record 5 of Set 5 | the valley
# Processing Record 6 of Set 5 | san quintin
# Processing Record 7 of Set 5 | qasigiannguit
# Processing Record 8 of Set 5 | zabol
# Processing Record 9 of Set 5 | scarborough
# Processing Record 10 of Set 5 | akureyri
# Processing Record 11 of Set 5 | yang talat
# Processing Record 12 of Set 5 | zyryanka
# Processing Record 13 of Set 5 | chuy
# Processing Record 14 of Set 5 | kumluca
# Processing Record 15 of Set 5 | hamilton
# Processing Record 16 of Set 5 | ankang
# Processing Record 17 of Set 5 | lagunas
# Processing Record 18 of Set 5 | codrington
# Processing Record 19 of Set 5 | sao filipe
# Processing Record 20 of Set 5 | shimoda
# Processing Record 21 of Set 5 | yantal
# Processing Record 22 of Set 5 | umba
# Processing Record 23 of Set 5 | samsun
# Processing Record 24 of Set 5 | khorixas
# Processing Record 25 of Set 5 | toumodi
# Processing Record 26 of Set 5 | bantou
# Processing Record 27 of Set 5 | iisalmi
# Processing Record 28 of Set 5 | lorengau
# Processing Record 29 of Set 5 | brae
# Processing Record 30 of Set 5 | rio grande
# Processing Record 31 of Set 5 | jiexiu
# Processing Record 32 of Set 5 | bol
# Processing Record 33 of Set 5 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 34 of Set 5 | hofn
# Processing Record 35 of Set 5 | deputatskiy
# Processing Record 36 of Set 5 | kirakira
# Processing Record 37 of Set 5 | katsuura
# Processing Record 38 of Set 5 | champerico
# Processing Record 39 of Set 5 | almeirim
# Processing Record 40 of Set 5 | tabou
# Processing Record 41 of Set 5 | saskylakh
# Processing Record 42 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 5 | tommot
# Processing Record 44 of Set 5 | mantua
# Processing Record 45 of Set 5 | la ronge
# Processing Record 46 of Set 5 | kokopo
# Processing Record 47 of Set 5 | nuuk
# Processing Record 48 of Set 5 | cascais
# Processing Record 49 of Set 5 | buala
# Processing Record 50 of Set 5 | palaia fokaia
# Processing Record 1 of Set 6 | hualmay
# Processing Record 2 of Set 6 | honavar
# Processing Record 3 of Set 6 | clyde river
# Processing Record 4 of Set 6 | high level
# Processing Record 5 of Set 6 | esperance
# Processing Record 6 of Set 6 | kahului
# Processing Record 7 of Set 6 | mana
# Processing Record 8 of Set 6 | shu
# Processing Record 9 of Set 6 | malpe
# Processing Record 10 of Set 6 | carnarvon
# Processing Record 11 of Set 6 | rocha
# Processing Record 12 of Set 6 | boguchany
# Processing Record 13 of Set 6 | san ramon
# Processing Record 14 of Set 6 | trincomalee
# Processing Record 15 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 16 of Set 6 | ust-tsilma
# Processing Record 17 of Set 6 | kedrovyy
# Processing Record 18 of Set 6 | ostrovnoy
# Processing Record 19 of Set 6 | apatou
# Processing Record 20 of Set 6 | chicama
# Processing Record 21 of Set 6 | cabedelo
# Processing Record 22 of Set 6 | ribeira grande
# Processing Record 23 of Set 6 | tasiilaq
# Processing Record 24 of Set 6 | mayumba
# Processing Record 25 of Set 6 | havoysund
# Processing Record 26 of Set 6 | uvalde
# Processing Record 27 of Set 6 | baykit
# Processing Record 28 of Set 6 | ladario
# Processing Record 29 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 6 | killybegs
# Processing Record 31 of Set 6 | manggar
# Processing Record 32 of Set 6 | santa cruz de tenerife
# Processing Record 33 of Set 6 | canton
# Processing Record 34 of Set 6 | nome
# Processing Record 35 of Set 6 | havelock
# Processing Record 36 of Set 6 | kirensk
# Processing Record 37 of Set 6 | palmer
# Processing Record 38 of Set 6 | san pedro de macoris
# Processing Record 39 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 6 | gilbues
# Processing Record 41 of Set 6 | luderitz
# Processing Record 42 of Set 6 | lazaro cardenas
# Processing Record 43 of Set 6 | carroll
# Processing Record 44 of Set 6 | olafsvik
# Processing Record 45 of Set 6 | marsh harbour
# Processing Record 46 of Set 6 | port elizabeth
# Processing Record 47 of Set 6 | kilakarai
# Processing Record 48 of Set 6 | dumjor
# Processing Record 49 of Set 6 | rinconada
# Processing Record 50 of Set 6 | saint-ambroise
# Processing Record 1 of Set 7 | turukhansk
# Processing Record 2 of Set 7 | diffa
# Processing Record 3 of Set 7 | peplos
# Processing Record 4 of Set 7 | thurso
# Processing Record 5 of Set 7 | beringovskiy
# Processing Record 6 of Set 7 | whitehorse
# Processing Record 7 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 8 of Set 7 | hambantota
# Processing Record 9 of Set 7 | san angelo
# Processing Record 10 of Set 7 | cururupu
# Processing Record 11 of Set 7 | zhezkazgan
# Processing Record 12 of Set 7 | handan
# Processing Record 13 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 7 | tvedestrand
# Processing Record 15 of Set 7 | xenia
# Processing Record 16 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 7 | tangwani
# Processing Record 19 of Set 7 | bereda
# Processing Record 20 of Set 7 | otavalo
# Processing Record 21 of Set 7 | chipinge
# Processing Record 22 of Set 7 | zhanaozen
# Processing Record 23 of Set 7 | buena vista
# Processing Record 24 of Set 7 | beira
# Processing Record 25 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 26 of Set 7 | antofagasta
# Processing Record 27 of Set 7 | bull savanna
# Processing Record 28 of Set 7 | east london
# Processing Record 29 of Set 7 | gwadar
# Processing Record 30 of Set 7 | gorontalo
# Processing Record 31 of Set 7 | zhigansk
# Processing Record 32 of Set 7 | pozo colorado
# Processing Record 33 of Set 7 | destin
# Processing Record 34 of Set 7 | goderich
# Processing Record 35 of Set 7 | saint-augustin
# Processing Record 36 of Set 7 | tirano
# Processing Record 37 of Set 7 | sinnai
# Processing Record 38 of Set 7 | manali
# Processing Record 39 of Set 7 | eyl
# Processing Record 40 of Set 7 | kloulklubed
# Processing Record 41 of Set 7 | tianpeng
# Processing Record 42 of Set 7 | lata
# Processing Record 43 of Set 7 | denpasar
# Processing Record 44 of Set 7 | lapao
# Processing Record 45 of Set 7 | chapais
# Processing Record 46 of Set 7 | kanniyakumari
# Processing Record 47 of Set 7 | sevlievo
# Processing Record 48 of Set 7 | ixtapa
# Processing Record 49 of Set 7 | sur
# Processing Record 50 of Set 7 | naze
# Processing Record 1 of Set 8 | garowe
# Processing Record 2 of Set 8 | saint george
# Processing Record 3 of Set 8 | ukiah
# Processing Record 4 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 8 | luena
# Processing Record 6 of Set 8 | camacha
# Processing Record 7 of Set 8 | arauca
# Processing Record 8 of Set 8 | khudumelapye
# Processing Record 9 of Set 8 | chisec
# Processing Record 10 of Set 8 | jijiga
# Processing Record 11 of Set 8 | moron
# Processing Record 12 of Set 8 | haines junction
# Processing Record 13 of Set 8 | almaznyy
# Processing Record 14 of Set 8 | bujoreni
# Processing Record 15 of Set 8 | mount isa
# Processing Record 16 of Set 8 | hervey bay
# Processing Record 17 of Set 8 | tura
# Processing Record 18 of Set 8 | tuatapere
# Processing Record 19 of Set 8 | leh
# Processing Record 20 of Set 8 | pacific grove
# Processing Record 21 of Set 8 | caravelas
# Processing Record 22 of Set 8 | chernyshevskiy
# Processing Record 23 of Set 8 | necochea
# Processing Record 24 of Set 8 | belem de sao francisco
# Processing Record 25 of Set 8 | sitka
# Processing Record 26 of Set 8 | gaoua
# Processing Record 27 of Set 8 | katangli
# Processing Record 28 of Set 8 | kyren
# Processing Record 29 of Set 8 | kholodnyy
# Processing Record 30 of Set 8 | peniche
# Processing Record 31 of Set 8 | shitkino
# Processing Record 32 of Set 8 | alfredo baquerizo moreno
# Processing Record 33 of Set 8 | pechenga
# Processing Record 34 of Set 8 | aykhal
# Processing Record 35 of Set 8 | mangochi
# Processing Record 36 of Set 8 | djambala
# Processing Record 37 of Set 8 | novo aripuana
# Processing Record 38 of Set 8 | chokwe
# Processing Record 39 of Set 8 | norman wells
# Processing Record 40 of Set 8 | rameswaram
# Processing Record 41 of Set 8 | nueva rosita
# Processing Record 42 of Set 8 | kuito
# Processing Record 43 of Set 8 | abu kamal
# Processing Record 44 of Set 8 | shubarshi
# Processing Record 45 of Set 8 | nouadhibou
# Processing Record 46 of Set 8 | margate
# Processing Record 47 of Set 8 | malanje
# Processing Record 48 of Set 8 | te anau
# Processing Record 49 of Set 8 | marawi
# Processing Record 50 of Set 8 | greenwood
# Processing Record 1 of Set 9 | alvorada
# Processing Record 2 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 3 of Set 9 | meulaboh
# Processing Record 4 of Set 9 | murindo
# Processing Record 5 of Set 9 | miraflores
# Processing Record 6 of Set 9 | victoria
# Processing Record 7 of Set 9 | horki
# Processing Record 8 of Set 9 | shakhtinsk
# Processing Record 9 of Set 9 | chalus
# Processing Record 10 of Set 9 | kutum
# Processing Record 11 of Set 9 | gander
# Processing Record 12 of Set 9 | acajutla
# Processing Record 13 of Set 9 | tual
# Processing Record 14 of Set 9 | gunjur
# Processing Record 15 of Set 9 | vila velha
# Processing Record 16 of Set 9 | hun
# Processing Record 17 of Set 9 | la serena
# Processing Record 18 of Set 9 | orlik
# Processing Record 19 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 20 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 21 of Set 9 | livingstonia
# Processing Record 22 of Set 9 | visnes
# Processing Record 23 of Set 9 | parnamirim
# Processing Record 24 of Set 9 | omsukchan
# Processing Record 25 of Set 9 | itaituba
# Processing Record 26 of Set 9 | ridgecrest
# Processing Record 27 of Set 9 | bowling green
# Processing Record 28 of Set 9 | sorland
# Processing Record 29 of Set 9 | marsa matruh
# Processing Record 30 of Set 9 | fairfield
# Processing Record 31 of Set 9 | nur
# Processing Record 32 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 33 of Set 9 | mogok
# Processing Record 34 of Set 9 | quatre cocos
# Processing Record 35 of Set 9 | camopi
# Processing Record 36 of Set 9 | sola
# Processing Record 37 of Set 9 | adra
# Processing Record 38 of Set 9 | hobyo
# Processing Record 39 of Set 9 | zlobin
# Processing Record 40 of Set 9 | hanzhong
# Processing Record 41 of Set 9 | alyangula
# Processing Record 42 of Set 9 | filadelfia
# Processing Record 43 of Set 9 | svetlogorsk
# Processing Record 44 of Set 9 | fukue
# Processing Record 45 of Set 9 | yarada
# Processing Record 46 of Set 9 | ballina
# Processing Record 47 of Set 9 | santiago de chuco
# Processing Record 48 of Set 9 | salmas
# Processing Record 49 of Set 9 | nizhniy tsasuchey
# Processing Record 50 of Set 9 | san vicente
# Processing Record 1 of Set 10 | kang
# Processing Record 2 of Set 10 | ilulissat
# Processing Record 3 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 10 | lasa
# Processing Record 5 of Set 10 | wamba
# Processing Record 6 of Set 10 | jumla
# Processing Record 7 of Set 10 | duku
# Processing Record 8 of Set 10 | ladispoli
# Processing Record 9 of Set 10 | chake chake
# Processing Record 10 of Set 10 | mundo nuevo
# Processing Record 11 of Set 10 | mandalgovi
# Processing Record 12 of Set 10 | porto novo
# Processing Record 13 of Set 10 | leningradskiy
# Processing Record 14 of Set 10 | kundiawa
# Processing Record 15 of Set 10 | gazanjyk
# Processing Record 16 of Set 10 | nouakchott
# Processing Record 17 of Set 10 | muroto
# Processing Record 18 of Set 10 | zwedru
# Processing Record 19 of Set 10 | carahue
# Processing Record 20 of Set 10 | qui nhon
# Processing Record 21 of Set 10 | calatayud
# Processing Record 22 of Set 10 | odweyne
# Processing Record 23 of Set 10 | maragogi
# Processing Record 24 of Set 10 | birin
# Processing Record 25 of Set 10 | sanghar
# Processing Record 26 of Set 10 | slave lake
# Processing Record 27 of Set 10 | george town
# Processing Record 28 of Set 10 | severo-yeniseyskiy
# Processing Record 29 of Set 10 | broome
# Processing Record 30 of Set 10 | magnitogorsk
# Processing Record 31 of Set 10 | xichang
# Processing Record 32 of Set 10 | bandarbeyla
# Processing Record 33 of Set 10 | dubbo
# Processing Record 34 of Set 10 | san rafael
# Processing Record 35 of Set 10 | micheldorf
# Processing Record 36 of Set 10 | shaoxing
# Processing Record 37 of Set 10 | san cristobal
# Processing Record 38 of Set 10 | plettenberg bay
# Processing Record 39 of Set 10 | roebourne
# Processing Record 40 of Set 10 | monrovia
# Processing Record 41 of Set 10 | socorro
# Processing Record 42 of Set 10 | noyabrsk
# Processing Record 43 of Set 10 | sabla
# Processing Record 44 of Set 10 | dzilam gonzalez
# Processing Record 45 of Set 10 | gubkinskiy
# Processing Record 46 of Set 10 | lagoa
# Processing Record 47 of Set 10 | ketchikan
# Processing Record 48 of Set 10 | novaya zaimka
# Processing Record 49 of Set 10 | coquimbo
# Processing Record 50 of Set 10 | west bay
# Processing Record 1 of Set 11 | kantang
# Processing Record 2 of Set 11 | oskaloosa
# Processing Record 3 of Set 11 | ulkan
# Processing Record 4 of Set 11 | gobabis
# Processing Record 5 of Set 11 | salinopolis
# Processing Record 6 of Set 11 | seminole
# Processing Record 7 of Set 11 | celestun
# Processing Record 8 of Set 11 | sao joao da barra
# Processing Record 9 of Set 11 | roswell
# Processing Record 10 of Set 11 | farah
# Processing Record 11 of Set 11 | cap malheureux
# Processing Record 12 of Set 11 | harigue
# City not found. Skipping...
# Processing Record 13 of Set 11 | canora
# Processing Record 14 of Set 11 | duayaw nkwanta
# Processing Record 15 of Set 11 | bealanana
# Processing Record 16 of Set 11 | touros
# Processing Record 17 of Set 11 | lompoc
# Processing Record 18 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 11 | lebyazhye
# Processing Record 20 of Set 11 | florianopolis
# Processing Record 21 of Set 11 | zell am see
# Processing Record 22 of Set 11 | joao camara
# Processing Record 23 of Set 11 | darhan
# Processing Record 24 of Set 11 | acari
# Processing Record 25 of Set 11 | japura
# Processing Record 26 of Set 11 | chichli
# Processing Record 27 of Set 11 | khash
# Processing Record 28 of Set 11 | sorgun
# Processing Record 29 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 30 of Set 11 | plouzane
# Processing Record 31 of Set 11 | wanning
# Processing Record 32 of Set 11 | brufut
# Processing Record 33 of Set 11 | mount gambier
# Processing Record 34 of Set 11 | ouesso
# Processing Record 35 of Set 11 | koboldo
# City not found. Skipping...
# Processing Record 36 of Set 11 | karla
# Processing Record 37 of Set 11 | glarus
# Processing Record 38 of Set 11 | jiwani
# Processing Record 39 of Set 11 | allapalli
# Processing Record 40 of Set 11 | zaysan
# Processing Record 41 of Set 11 | joshimath
# Processing Record 42 of Set 11 | qaqortoq
# Processing Record 43 of Set 11 | smithers
# Processing Record 44 of Set 11 | alberton
# Processing Record 45 of Set 11 | preveza
# Processing Record 46 of Set 11 | nanortalik
# Processing Record 47 of Set 11 | husavik
# Processing Record 48 of Set 11 | anar darreh
# City not found. Skipping...
# Processing Record 49 of Set 11 | neiafu
# Processing Record 50 of Set 11 | budhlada
# Processing Record 1 of Set 12 | fuyu
# Processing Record 2 of Set 12 | oum hadjer
# Processing Record 3 of Set 12 | port lincoln
# Processing Record 4 of Set 12 | lindi
# Processing Record 5 of Set 12 | lensk
# Processing Record 6 of Set 12 | putina
# Processing Record 7 of Set 12 | port macquarie
# Processing Record 8 of Set 12 | mayo
# Processing Record 9 of Set 12 | san pedro
# Processing Record 10 of Set 12 | nha trang
# Processing Record 11 of Set 12 | minab
# Processing Record 12 of Set 12 | prado
# Processing Record 13 of Set 12 | maple creek
# Processing Record 14 of Set 12 | sarahan
# Processing Record 15 of Set 12 | hokitika
# Processing Record 16 of Set 12 | salekhard
# Processing Record 17 of Set 12 | neos marmaras
# Processing Record 18 of Set 12 | tezu
# Processing Record 19 of Set 12 | chivay
# Processing Record 20 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 12 | san policarpo
# Processing Record 22 of Set 12 | puerto del rosario
# Processing Record 23 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 12 | tilichiki
# Processing Record 25 of Set 12 | berlevag
# Processing Record 26 of Set 12 | solnechnyy
# Processing Record 27 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 28 of Set 12 | puerto escondido
# Processing Record 29 of Set 12 | luquillo
# Processing Record 30 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 31 of Set 12 | pitkyaranta
# Processing Record 32 of Set 12 | fuerte olimpo
# Processing Record 33 of Set 12 | aksarka
# Processing Record 34 of Set 12 | prince george
# Processing Record 35 of Set 12 | idlib
# Processing Record 36 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 12 | cefalu
# Processing Record 38 of Set 12 | bonavista
# Processing Record 39 of Set 12 | ashcroft
# Processing Record 40 of Set 12 | havre-saint-pierre
# Processing Record 41 of Set 12 | tiznit
# Processing Record 42 of Set 12 | nirasaki
# Processing Record 43 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 44 of Set 12 | praia da vitoria
# Processing Record 45 of Set 12 | samarai
# Processing Record 46 of Set 12 | jizan
# Processing Record 47 of Set 12 | harriston
# Processing Record 48 of Set 12 | hauge
# Processing Record 49 of Set 12 | pishin
# Processing Record 50 of Set 12 | belmonte
# Processing Record 1 of Set 13 | abnub
# Processing Record 2 of Set 13 | antalaha
# Processing Record 3 of Set 13 | honningsvag
# Processing Record 4 of Set 13 | oranjemund
# Processing Record 5 of Set 13 | matagami
# Processing Record 6 of Set 13 | gazojak
# Processing Record 7 of Set 13 | langsa
# Processing Record 8 of Set 13 | yar-sale
# Processing Record 9 of Set 13 | nampula
# Processing Record 10 of Set 13 | kavaratti
# Processing Record 11 of Set 13 | opuwo
# Processing Record 12 of Set 13 | arica
# Processing Record 13 of Set 13 | iskateley
# Processing Record 14 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 13 | sawakin
# Processing Record 16 of Set 13 | pinheiro machado
# Processing Record 17 of Set 13 | emba
# Processing Record 18 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 13 | eureka
# Processing Record 20 of Set 13 | salinas
# Processing Record 21 of Set 13 | raudeberg
# Processing Record 22 of Set 13 | talaya
# Processing Record 23 of Set 13 | batagay-alyta
# Processing Record 24 of Set 13 | viseu
# Processing Record 25 of Set 13 | xuanzhou
# Processing Record 26 of Set 13 | madinat sittah uktubar
# Processing Record 27 of Set 13 | gravdal
# Processing Record 28 of Set 13 | montepuez
# Processing Record 29 of Set 13 | saint anthony
# Processing Record 30 of Set 13 | kozhevnikovo
# Processing Record 31 of Set 13 | wajid
# Processing Record 32 of Set 13 | muros
# Processing Record 33 of Set 13 | waipawa
# Processing Record 34 of Set 13 | marshfield
# Processing Record 35 of Set 13 | kentau
# Processing Record 36 of Set 13 | jasper
# Processing Record 37 of Set 13 | carballo
# Processing Record 38 of Set 13 | itarema
# Processing Record 39 of Set 13 | soyo
# Processing Record 40 of Set 13 | placido de castro
# Processing Record 41 of Set 13 | yate
# Processing Record 42 of Set 13 | lake city
# Processing Record 43 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 13 | tchollire
# Processing Record 45 of Set 13 | charagua
# Processing Record 46 of Set 13 | ewa beach
# Processing Record 47 of Set 13 | umm kaddadah
# Processing Record 48 of Set 13 | rio gallegos
# Processing Record 49 of Set 13 | san bartolome de tirajana
# Processing Record 50 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 14 | kyra
# Processing Record 2 of Set 14 | ust-omchug
# Processing Record 3 of Set 14 | sishui
# Processing Record 4 of Set 14 | manoel urbano
# Processing Record 5 of Set 14 | nishihara
# Processing Record 6 of Set 14 | katra
# Processing Record 7 of Set 14 | darnah
# Processing Record 8 of Set 14 | korla
# Processing Record 9 of Set 14 | funadhoo
# Processing Record 10 of Set 14 | nacozari
# Processing Record 11 of Set 14 | ambilobe
# Processing Record 12 of Set 14 | sterling
# Processing Record 13 of Set 14 | urumqi
# Processing Record 14 of Set 14 | evensk
# Processing Record 15 of Set 14 | masuguru
# Processing Record 16 of Set 14 | qandala
# Processing Record 17 of Set 14 | kitimat
# Processing Record 18 of Set 14 | moose jaw
# Processing Record 19 of Set 14 | pringsewu
# Processing Record 20 of Set 14 | arkhangelsk
# Processing Record 21 of Set 14 | ryotsu
# Processing Record 22 of Set 14 | domoni
# Processing Record 23 of Set 14 | rockland
# Processing Record 24 of Set 14 | kibungo
# Processing Record 25 of Set 14 | namibe
# Processing Record 26 of Set 14 | hay river
# Processing Record 27 of Set 14 | pundaguitan
# Processing Record 28 of Set 14 | marinette
# Processing Record 29 of Set 14 | lithakia
# Processing Record 30 of Set 14 | mineiros
# Processing Record 31 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 14 | erzin
# Processing Record 33 of Set 14 | ossora
# Processing Record 34 of Set 14 | perth
# Processing Record 35 of Set 14 | ekhabi
# Processing Record 36 of Set 14 | chingola
# Processing Record 37 of Set 14 | sisimiut
# Processing Record 38 of Set 14 | sandwick
# Processing Record 39 of Set 14 | makaha
# Processing Record 40 of Set 14 | cavaillon
# Processing Record 41 of Set 14 | sakakah
# Processing Record 42 of Set 14 | otukpo
# Processing Record 43 of Set 14 | porbandar
# Processing Record 44 of Set 14 | saint-pierre
# Processing Record 45 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 14 | henties bay
# Processing Record 47 of Set 14 | bazarnyye mataki
# Processing Record 48 of Set 14 | emmett
# Processing Record 49 of Set 14 | vallenar
# Processing Record 50 of Set 14 | saryozek
# Processing Record 1 of Set 15 | daru
# Processing Record 2 of Set 15 | cassilandia
# Processing Record 3 of Set 15 | luzzi
# Processing Record 4 of Set 15 | lalsk
# Processing Record 5 of Set 15 | hendijan
# City not found. Skipping...
# Processing Record 6 of Set 15 | ozernovskiy
# Processing Record 7 of Set 15 | erenhot
# Processing Record 8 of Set 15 | kaili
# Processing Record 9 of Set 15 | lluta
# Processing Record 10 of Set 15 | menongue
# Processing Record 11 of Set 15 | richards bay
# Processing Record 12 of Set 15 | hermosillo
# Processing Record 13 of Set 15 | prieska
# Processing Record 14 of Set 15 | vitim
# Processing Record 15 of Set 15 | ramygala
# Processing Record 16 of Set 15 | sibolga
# Processing Record 17 of Set 15 | shelburne
# Processing Record 18 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 19 of Set 15 | south river
# Processing Record 20 of Set 15 | hirara
# Processing Record 21 of Set 15 | junagarh
# Processing Record 22 of Set 15 | staryy nadym
# Processing Record 23 of Set 15 | vladimirescu
# Processing Record 24 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 15 | iguape
# Processing Record 26 of Set 15 | luba
# Processing Record 27 of Set 15 | pinawa
# Processing Record 28 of Set 15 | beloha
# Processing Record 29 of Set 15 | san jose
# Processing Record 30 of Set 15 | kyshtovka
# Processing Record 31 of Set 15 | sakyla
# Processing Record 32 of Set 15 | roald
# Processing Record 33 of Set 15 | salta
# Processing Record 34 of Set 15 | meiganga
# Processing Record 35 of Set 15 | nacala
# Processing Record 36 of Set 15 | poltavka
# Processing Record 37 of Set 15 | talara
# Processing Record 38 of Set 15 | norden
# Processing Record 39 of Set 15 | belyy yar
# Processing Record 40 of Set 15 | sao miguel do araguaia
# Processing Record 41 of Set 15 | thinadhoo
# Processing Record 42 of Set 15 | yanam
# Processing Record 43 of Set 15 | morant bay
# Processing Record 44 of Set 15 | jalu
# Processing Record 45 of Set 15 | nisia floresta
# Processing Record 46 of Set 15 | bratsk
# Processing Record 47 of Set 15 | kardailovo
# Processing Record 48 of Set 15 | vila
# Processing Record 49 of Set 15 | mokhsogollokh
# Processing Record 50 of Set 15 | nioro
# Processing Record 1 of Set 16 | karratha
# Processing Record 2 of Set 16 | pokaran
# Processing Record 3 of Set 16 | moree
# Processing Record 4 of Set 16 | loei
# Processing Record 5 of Set 16 | pyapon
# Processing Record 6 of Set 16 | oyama
# Processing Record 7 of Set 16 | cumaral
# Processing Record 8 of Set 16 | muli
# Processing Record 9 of Set 16 | aljezur
# Processing Record 10 of Set 16 | toora-khem
# Processing Record 11 of Set 16 | orocue
# Processing Record 12 of Set 16 | rio verde de mato grosso
# Processing Record 13 of Set 16 | hami
# Processing Record 14 of Set 16 | viedma
# Processing Record 15 of Set 16 | patacamaya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(11)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas      CL -53.1500  -70.9167     46.40        61          40
# 1       Thompson      CA  55.7435  -97.8558     42.80        31          75
# 2           Hilo      US  19.7297 -155.0900     78.80        61          90
# 3      Hithadhoo      MV  -0.6000   73.0833     83.12        75          72
# 4      Grindavik      IS  63.8424  -22.4338     17.60        57          75
# 5      Egvekinot      RU  66.3167 -179.1667     -2.92        75          34
# 6         Albany      US  42.6001  -73.9662     59.00        44          43
# 7          Airai      TL  -8.9266  125.4092     60.08        95         100
# 8      Tonekabon      IR  36.8163   50.8738     51.80        76           0
# 9       Tuskegee      US  32.4240  -85.6916     73.00        28           1
# 10    Butaritari      KI   3.0707  172.7902     82.22        79          80
#
#     Wind Speed Current Description
# 0        19.57    scattered clouds
# 1         6.91       broken clouds
# 2         3.44     overcast clouds
# 3        17.49       broken clouds
# 4        13.80       broken clouds
# 5         2.77    scattered clouds
# 6         1.99    scattered clouds
# 7         3.36     overcast clouds
# 8         2.30           clear sky
# 9         8.05           clear sky
# 10       16.33       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City ID")
